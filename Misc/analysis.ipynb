# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from omegaconf import OmegaConf
import numpy as np

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
def load_all_experiments(experiments_root="outputs/experiments"):
    """Load all experiments from the outputs directory"""
    experiments_path = Path(experiments_root)
    experiments = []
    
    if not experiments_path.exists():
        print(f"Directory {experiments_root} doesn't exist")
        return experiments
    
    for exp_name_dir in experiments_path.iterdir():
        if not exp_name_dir.is_dir():
            continue
            
        print(f"Scanning experiment: {exp_name_dir.name}")
        
        for timestamp_dir in exp_name_dir.iterdir():
            if not timestamp_dir.is_dir():
                continue
                
            # Check for Hydra config (always exists) and our loss file
            config_file = timestamp_dir / ".hydra" / "config.yaml"
            loss_file = timestamp_dir / "loss_summary.txt"
            
            if config_file.exists():  # Hydra config should always exist
                try:
                    # Load config
                    config = OmegaConf.load(config_file)
                    
                    # Load losses if available
                    best_loss = float('inf')
                    final_loss = float('inf')
                    
                    if loss_file.exists():
                        with open(loss_file, 'r') as f:
                            for line in f:
                                if line.startswith('best_loss='):
                                    best_loss = float(line.split('=')[1].strip())
                                elif line.startswith('final_loss='):
                                    final_loss = float(line.split('=')[1].strip())
                    
                    # Create summary from config and loss data
                    summary = {
                        'experiment_name': config.experiment.name,
                        'best_loss': best_loss,
                        'final_loss': final_loss,
                        'has_loss_data': loss_file.exists(),
                        'total_steps': config.training.max_steps,
                        'architecture': {
                            'potential_layers': config.arch.potential.hidden_layers,
                            'potential_size': config.arch.potential.layer_size,
                            'cv_layers': config.arch.CV.hidden_layers,
                            'cv_size': config.arch.CV.layer_size,
                        }
                    }
                    
                    experiment = {
                        'name': exp_name_dir.name,
                        'timestamp': timestamp_dir.name,
                        'path': str(timestamp_dir),
                        'config': config,
                        'summary': summary
                    }
                    
                    experiments.append(experiment)
                    if loss_file.exists():
                        print(f"  ✅ Loaded run: {timestamp_dir.name}")
                    else:
                        print(f"  📋 Loaded run: {timestamp_dir.name} (config only)")
                        
                except Exception as e:
                    print(f"  ❌ Error loading {timestamp_dir.name}: {e}")
    
    print(f"\nTotal experiments loaded: {len(experiments)}")
    return experiments

# %%
# Cell 3: Load Your Experiments
experiments = load_all_experiments()

# Display what we found
for exp in experiments[-5:]:  # Show last 5
    print(f"{exp['name']} ({exp['timestamp']}) - Best Loss: {exp['summary']['best_loss']:.2e}")
# Out:
# Scanning experiment: base_reduced_ntk_scheduler_tests
#   📋 Loaded run: 2025-06-20_14-56-19 (config only)
#   📋 Loaded run: 2025-06-20_14-38-55 (config only)
#   📋 Loaded run: 2025-06-20_14-44-04 (config only)
# Scanning experiment: nexPINNACLE_reduced_interior_sampling
#   📋 Loaded run: 2025-06-18_15-07-00 (config only)
# Scanning experiment: base_reduced_ntk_activation_tests
#   📋 Loaded run: 2025-06-19_17-53-59 (config only)
#   📋 Loaded run: 2025-06-19_17-28-33 (config only)
#   📋 Loaded run: 2025-06-19_17-41-07 (config only)
#   📋 Loaded run: 2025-06-19_16-58-07 (config only)
#   📋 Loaded run: 2025-06-19_17-13-46 (config only)
#   📋 Loaded run: 2025-06-19_17-19-47 (config only)
#   📋 Loaded run: 2025-06-19_16-54-18 (config only)
# Scanning experiment: base+ntk
#   📋 Loaded run: 2025-06-18_14-54-06 (config only)
#   📋 Loaded run: 2025-06-18_14-16-30 (config only)
#   📋 Loaded run: 2025-06-18_13-44-25 (config only)
#   📋 Loaded run: 2025-06-18_13-44-45 (config only)
#   📋 Loaded run: 2025-06-18_13-43-34 (config only)
#   📋 Loaded run: 2025-06-18_14-16-48 (config only)
#   📋 Loaded run: 2025-06-18_14-19-23 (config only)
#   📋 Loaded run: 2025-06-18_14-51-30 (config only)
#   📋 Loaded run: 2025-06-18_14-48-28 (config only)
#   📋 Loaded run: 2025-06-18_14-50-18 (config only)
#   📋 Loaded run: 2025-06-18_14-57-13 (config only)
#   📋 Loaded run: 2025-06-18_14-06-04 (config only)
#   📋 Loaded run: 2025-06-18_14-09-45 (config only)
#   📋 Loaded run: 2025-06-18_14-53-12 (config only)
# Scanning experiment: base_reduced_ntk_architecture_tests
#   📋 Loaded run: 2025-06-23_14-29-55 (config only)
#   📋 Loaded run: 2025-06-23_14-27-24 (config only)
#   ✅ Loaded run: 2025-06-24_12-11-58
#   📋 Loaded run: 2025-06-23_12-40-17 (config only)
#   📋 Loaded run: 2025-06-23_14-28-57 (config only)
#   📋 Loaded run: 2025-06-23_14-28-36 (config only)
# Scanning experiment: base_reduced_ntk_softplus
#   📋 Loaded run: 2025-06-19_16-45-21 (config only)
# Scanning experiment: base_reduced_ntk_xavier_init_test
#   📋 Loaded run: 2025-06-20_15-38-57 (config only)
#   📋 Loaded run: 2025-06-20_15-40-33 (config only)
#   📋 Loaded run: 2025-06-20_15-35-54 (config only)
#   📋 Loaded run: 2025-06-20_15-44-40 (config only)
#   📋 Loaded run: 2025-06-20_15-40-22 (config only)
# Scanning experiment: base+ntk_reduced_interior_points_quicker_updates
#   📋 Loaded run: 2025-06-19_16-19-30 (config only)
#   📋 Loaded run: 2025-06-19_16-29-09 (config only)
#   📋 Loaded run: 2025-06-19_15-59-07 (config only)
#   📋 Loaded run: 2025-06-19_15-59-37 (config only)
# Scanning experiment: base_reduced_softplus
#   📋 Loaded run: 2025-06-19_16-37-19 (config only)
#   📋 Loaded run: 2025-06-19_16-37-26 (config only)
# Scanning experiment: base_reduced_weight_tests
#   📋 Loaded run: 2025-06-20_12-18-15 (config only)
#   📋 Loaded run: 2025-06-20_12-20-15 (config only)
#   📋 Loaded run: 2025-06-20_12-15-46 (config only)
# Scanning experiment: NexPINNACLE
#   📋 Loaded run: 2025-06-18_10-38-18 (config only)
#   📋 Loaded run: 2025-06-17_16-01-31 (config only)
#   📋 Loaded run: 2025-06-18_12-53-03 (config only)
#   📋 Loaded run: 2025-06-17_15-59-28 (config only)
#   📋 Loaded run: 2025-06-17_16-01-05 (config only)
#   📋 Loaded run: 2025-06-18_12-53-21 (config only)
#   📋 Loaded run: 2025-06-17_16-39-54 (config only)
#   📋 Loaded run: 2025-06-17_16-45-04 (config only)
#   📋 Loaded run: 2025-06-17_16-11-37 (config only)
#   📋 Loaded run: 2025-06-18_11-29-08 (config only)
#   📋 Loaded run: 2025-06-17_16-00-50 (config only)
#   📋 Loaded run: 2025-06-18_11-36-18 (config only)
#   📋 Loaded run: 2025-06-17_16-05-27 (config only)
#   📋 Loaded run: 2025-06-17_16-01-57 (config only)
#   📋 Loaded run: 2025-06-17_16-01-43 (config only)
#   📋 Loaded run: 2025-06-17_15-59-46 (config only)
#   📋 Loaded run: 2025-06-17_16-41-28 (config only)
#   📋 Loaded run: 2025-06-17_16-00-12 (config only)
# Scanning experiment: base+ntk_reduced_interior_points_delayed_ntk
#   📋 Loaded run: 2025-06-19_15-51-10 (config only)
#   📋 Loaded run: 2025-06-19_15-51-34 (config only)
#   📋 Loaded run: 2025-06-19_13-36-46 (config only)
# Scanning experiment: base+ntk_reduced_interior_sampling
#   📋 Loaded run: 2025-06-18_15-25-07 (config only)
#   📋 Loaded run: 2025-06-18_15-43-21 (config only)
#   📋 Loaded run: 2025-06-18_15-26-14 (config only)
#   📋 Loaded run: 2025-06-18_15-20-23 (config only)
#   📋 Loaded run: 2025-06-18_15-17-29 (config only)
#   📋 Loaded run: 2025-06-18_15-30-46 (config only)
#   📋 Loaded run: 2025-06-18_15-22-48 (config only)
#   📋 Loaded run: 2025-06-18_16-15-11 (config only)
#   📋 Loaded run: 2025-06-18_15-18-51 (config only)
#   📋 Loaded run: 2025-06-18_15-28-36 (config only)
#   📋 Loaded run: 2025-06-18_15-37-04 (config only)
#   📋 Loaded run: 2025-06-18_15-54-14 (config only)
#   📋 Loaded run: 2025-06-18_15-32-32 (config only)
#
# Total experiments loaded: 80
# base+ntk_reduced_interior_sampling (2025-06-18_15-18-51) - Best Loss: inf
# base+ntk_reduced_interior_sampling (2025-06-18_15-28-36) - Best Loss: inf
# base+ntk_reduced_interior_sampling (2025-06-18_15-37-04) - Best Loss: inf
# base+ntk_reduced_interior_sampling (2025-06-18_15-54-14) - Best Loss: inf
# base+ntk_reduced_interior_sampling (2025-06-18_15-32-32) - Best Loss: inf
